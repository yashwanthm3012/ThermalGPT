# %%
import os
import numpy as np
import pyvista as pv

# Parameters for the simulation
alpha = 0.01  # Thermal diffusivity
nx, ny = 100, 100  # Number of grid points in x and y
nt = 100  # Number of timesteps
dt = 0.01  # Time step size

# Spatial grid
x = np.linspace(0, 1, nx)
y = np.linspace(0, 1, ny)
dx = x[1] - x[0]
dy = y[1] - y[0]
X, Y = np.meshgrid(x, y)

# Initialize temperature field
T = np.sin(np.pi * X) * np.sin(np.pi * Y)  # Initial condition
T_new = T.copy()

# Boundary conditions
def apply_boundary_conditions(T):
    T[:, 0] = 0  # Bottom boundary
    T[:, -1] = 0  # Top boundary
    T[0, :] = 0  # Left boundary
    T[-1, :] = 0  # Right boundary
    return T

# Function to update temperature using FDM
def update_temperature(T, T_new, alpha, dt, dx, dy):
    for i in range(1, nx - 1):
        for j in range(1, ny - 1):
            T_new[i, j] = (
                T[i, j]
                + alpha * dt * (
                    (T[i + 1, j] - 2 * T[i, j] + T[i - 1, j]) / dx**2
                    + (T[i, j + 1] - 2 * T[i, j] + T[i, j - 1]) / dy**2
                )
            )
    return apply_boundary_conditions(T_new)

# Generate VTK files
output_dir = "./working/"
os.makedirs(output_dir, exist_ok=True)

for t in range(nt):
    T_new = update_temperature(T, T_new, alpha, dt, dx, dy)
    T[:] = T_new  # Update temperature field
    
    # Create PyVista grid
    Z = np.zeros_like(X)
    grid = pv.StructuredGrid(X, Y, Z)
    grid["Temperature"] = T.ravel(order="F")
    
    # Save VTK file
    filename = os.path.join(output_dir, f"Field_{t:03d}.vtk")
    grid.save(filename)
    print(f"File saved: {filename}")
# Out:
# File saved: ./working/Field_000.vtk
# File saved: ./working/Field_001.vtk
# File saved: ./working/Field_002.vtk
# File saved: ./working/Field_003.vtk
# File saved: ./working/Field_004.vtk
# File saved: ./working/Field_005.vtk
# File saved: ./working/Field_006.vtk
# File saved: ./working/Field_007.vtk
# File saved: ./working/Field_008.vtk
# File saved: ./working/Field_009.vtk
# File saved: ./working/Field_010.vtk
# File saved: ./working/Field_011.vtk
# File saved: ./working/Field_012.vtk
# File saved: ./working/Field_013.vtk
# File saved: ./working/Field_014.vtk
# File saved: ./working/Field_015.vtk
# File saved: ./working/Field_016.vtk
# File saved: ./working/Field_017.vtk
# File saved: ./working/Field_018.vtk
# File saved: ./working/Field_019.vtk
# File saved: ./working/Field_020.vtk
# File saved: ./working/Field_021.vtk
# File saved: ./working/Field_022.vtk
# File saved: ./working/Field_023.vtk
# File saved: ./working/Field_024.vtk
# File saved: ./working/Field_025.vtk
# File saved: ./working/Field_026.vtk
# File saved: ./working/Field_027.vtk
# File saved: ./working/Field_028.vtk
# File saved: ./working/Field_029.vtk
# File saved: ./working/Field_030.vtk
# File saved: ./working/Field_031.vtk
# File saved: ./working/Field_032.vtk
# File saved: ./working/Field_033.vtk
# File saved: ./working/Field_034.vtk
# File saved: ./working/Field_035.vtk
# File saved: ./working/Field_036.vtk
# File saved: ./working/Field_037.vtk
# File saved: ./working/Field_038.vtk
# File saved: ./working/Field_039.vtk
# File saved: ./working/Field_040.vtk
# File saved: ./working/Field_041.vtk
# File saved: ./working/Field_042.vtk
# File saved: ./working/Field_043.vtk
# File saved: ./working/Field_044.vtk
# File saved: ./working/Field_045.vtk
# File saved: ./working/Field_046.vtk
# File saved: ./working/Field_047.vtk
# File saved: ./working/Field_048.vtk
# File saved: ./working/Field_049.vtk
# File saved: ./working/Field_050.vtk
# File saved: ./working/Field_051.vtk
# File saved: ./working/Field_052.vtk
# File saved: ./working/Field_053.vtk
# File saved: ./working/Field_054.vtk
# File saved: ./working/Field_055.vtk
# File saved: ./working/Field_056.vtk
# File saved: ./working/Field_057.vtk
# File saved: ./working/Field_058.vtk
# File saved: ./working/Field_059.vtk
# File saved: ./working/Field_060.vtk
# File saved: ./working/Field_061.vtk
# File saved: ./working/Field_062.vtk
# File saved: ./working/Field_063.vtk
# File saved: ./working/Field_064.vtk
# File saved: ./working/Field_065.vtk
# File saved: ./working/Field_066.vtk
# File saved: ./working/Field_067.vtk
# File saved: ./working/Field_068.vtk
# File saved: ./working/Field_069.vtk
# File saved: ./working/Field_070.vtk
# File saved: ./working/Field_071.vtk
# File saved: ./working/Field_072.vtk
# File saved: ./working/Field_073.vtk
# File saved: ./working/Field_074.vtk
# File saved: ./working/Field_075.vtk
# File saved: ./working/Field_076.vtk
# File saved: ./working/Field_077.vtk
# File saved: ./working/Field_078.vtk
# File saved: ./working/Field_079.vtk
# File saved: ./working/Field_080.vtk
# File saved: ./working/Field_081.vtk
# File saved: ./working/Field_082.vtk
# File saved: ./working/Field_083.vtk
# File saved: ./working/Field_084.vtk
# File saved: ./working/Field_085.vtk
# File saved: ./working/Field_086.vtk
# File saved: ./working/Field_087.vtk
# File saved: ./working/Field_088.vtk
# File saved: ./working/Field_089.vtk
# File saved: ./working/Field_090.vtk
# File saved: ./working/Field_091.vtk
# File saved: ./working/Field_092.vtk
# File saved: ./working/Field_093.vtk
# File saved: ./working/Field_094.vtk
# File saved: ./working/Field_095.vtk
# File saved: ./working/Field_096.vtk
# File saved: ./working/Field_097.vtk
# File saved: ./working/Field_098.vtk
# File saved: ./working/Field_099.vtk

# %%
import os
import numpy as np
import pyvista as pv

def temp_field_case2(x, y, scale=1.0):
    """
    Temperature field for Case 2:
    Solves the steady-state heat equation with the given boundary conditions.
    """
    return scale * (x**2 +y**2)

def generate_vtk(solution_func, filename, nx=100, ny=100, **kwargs):
    """
    Generate a VTK file for a given temperature field function.
    """
    # Ensure output directory exists
    output_dir = "./working/"
    os.makedirs(output_dir, exist_ok=True)
    
    # Create mesh grid
    x = np.linspace(0, 1, nx)
    y = np.linspace(0, 1, ny)
    X, Y = np.meshgrid(x, y)
    Z = np.zeros_like(X)  # For 2D data, Z is set to zero
    
    # Calculate solution
    temperature = solution_func(X, Y, **kwargs)
    
    # Create a PyVista grid
    grid = pv.StructuredGrid(X, Y, Z)
    grid["Temperature"] = temperature.ravel(order="F")  # Flatten for VTK format
    
    # Save the grid to a .vtk file
    file_path = os.path.join(output_dir, f"{filename}.vtk")
    grid.save(file_path)
    print(f"File saved to: {file_path}")

# Generate 100 VTK files with varying scale factors
for i in range(1, 101):
    scale = 1 + (i - 1) * 0.08  # Increment scale factor from 1.0 to 2.0
    filename = f"Field2_{i:03d}"
    generate_vtk(temp_field_case2, filename, scale=scale)
# Out:
# File saved to: ./working/Field2_001.vtk
# File saved to: ./working/Field2_002.vtk
# File saved to: ./working/Field2_003.vtk
# File saved to: ./working/Field2_004.vtk
# File saved to: ./working/Field2_005.vtk
# File saved to: ./working/Field2_006.vtk
# File saved to: ./working/Field2_007.vtk
# File saved to: ./working/Field2_008.vtk
# File saved to: ./working/Field2_009.vtk
# File saved to: ./working/Field2_010.vtk
# File saved to: ./working/Field2_011.vtk
# File saved to: ./working/Field2_012.vtk
# File saved to: ./working/Field2_013.vtk
# File saved to: ./working/Field2_014.vtk
# File saved to: ./working/Field2_015.vtk
# File saved to: ./working/Field2_016.vtk
# File saved to: ./working/Field2_017.vtk
# File saved to: ./working/Field2_018.vtk
# File saved to: ./working/Field2_019.vtk
# File saved to: ./working/Field2_020.vtk
# File saved to: ./working/Field2_021.vtk
# File saved to: ./working/Field2_022.vtk
# File saved to: ./working/Field2_023.vtk
# File saved to: ./working/Field2_024.vtk
# File saved to: ./working/Field2_025.vtk
# File saved to: ./working/Field2_026.vtk
# File saved to: ./working/Field2_027.vtk
# File saved to: ./working/Field2_028.vtk
# File saved to: ./working/Field2_029.vtk
# File saved to: ./working/Field2_030.vtk
# File saved to: ./working/Field2_031.vtk
# File saved to: ./working/Field2_032.vtk
# File saved to: ./working/Field2_033.vtk
# File saved to: ./working/Field2_034.vtk
# File saved to: ./working/Field2_035.vtk
# File saved to: ./working/Field2_036.vtk
# File saved to: ./working/Field2_037.vtk
# File saved to: ./working/Field2_038.vtk
# File saved to: ./working/Field2_039.vtk
# File saved to: ./working/Field2_040.vtk
# File saved to: ./working/Field2_041.vtk
# File saved to: ./working/Field2_042.vtk
# File saved to: ./working/Field2_043.vtk
# File saved to: ./working/Field2_044.vtk
# File saved to: ./working/Field2_045.vtk
# File saved to: ./working/Field2_046.vtk
# File saved to: ./working/Field2_047.vtk
# File saved to: ./working/Field2_048.vtk
# File saved to: ./working/Field2_049.vtk
# File saved to: ./working/Field2_050.vtk
# File saved to: ./working/Field2_051.vtk
# File saved to: ./working/Field2_052.vtk
# File saved to: ./working/Field2_053.vtk
# File saved to: ./working/Field2_054.vtk
# File saved to: ./working/Field2_055.vtk
# File saved to: ./working/Field2_056.vtk
# File saved to: ./working/Field2_057.vtk
# File saved to: ./working/Field2_058.vtk
# File saved to: ./working/Field2_059.vtk
# File saved to: ./working/Field2_060.vtk
# File saved to: ./working/Field2_061.vtk
# File saved to: ./working/Field2_062.vtk
# File saved to: ./working/Field2_063.vtk
# File saved to: ./working/Field2_064.vtk
# File saved to: ./working/Field2_065.vtk
# File saved to: ./working/Field2_066.vtk
# File saved to: ./working/Field2_067.vtk
# File saved to: ./working/Field2_068.vtk
# File saved to: ./working/Field2_069.vtk
# File saved to: ./working/Field2_070.vtk
# File saved to: ./working/Field2_071.vtk
# File saved to: ./working/Field2_072.vtk
# File saved to: ./working/Field2_073.vtk
# File saved to: ./working/Field2_074.vtk
# File saved to: ./working/Field2_075.vtk
# File saved to: ./working/Field2_076.vtk
# File saved to: ./working/Field2_077.vtk
# File saved to: ./working/Field2_078.vtk
# File saved to: ./working/Field2_079.vtk
# File saved to: ./working/Field2_080.vtk
# File saved to: ./working/Field2_081.vtk
# File saved to: ./working/Field2_082.vtk
# File saved to: ./working/Field2_083.vtk
# File saved to: ./working/Field2_084.vtk
# File saved to: ./working/Field2_085.vtk
# File saved to: ./working/Field2_086.vtk
# File saved to: ./working/Field2_087.vtk
# File saved to: ./working/Field2_088.vtk
# File saved to: ./working/Field2_089.vtk
# File saved to: ./working/Field2_090.vtk
# File saved to: ./working/Field2_091.vtk
# File saved to: ./working/Field2_092.vtk
# File saved to: ./working/Field2_093.vtk
# File saved to: ./working/Field2_094.vtk
# File saved to: ./working/Field2_095.vtk
# File saved to: ./working/Field2_096.vtk
# File saved to: ./working/Field2_097.vtk
# File saved to: ./working/Field2_098.vtk
# File saved to: ./working/Field2_099.vtk
# File saved to: ./working/Field2_100.vtk
